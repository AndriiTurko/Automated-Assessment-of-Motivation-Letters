# %%
import pandas as pd
import numpy as np

from assessment.motivation_letter_assessor import count_total

# %%
df = pd.read_csv('../data/letters_with_grammar.csv')

# %%
questions_percentiles = {}

for col in df.columns:
    if col.startswith('question_'):
        all_scores = df[col].dropna()  # Drop NaN values to avoid errors
        questions_percentiles[col] = np.percentile(all_scores, [5, 20, 40, 70, 90])

# %%
questions_percentiles
# Out:
# {'question_1': array([0.25605044, 0.32888703, 0.37261043, 0.44196429, 0.50736603]),
#  'question_2': array([0.27108292, 0.34387925, 0.39831877, 0.47050882, 0.5395731 ]),
#  'question_3': array([0.2556844 , 0.34676914, 0.39169471, 0.44504784, 0.50376501]),
#  'question_4': array([0.29287933, 0.34822476, 0.38855073, 0.4413141 , 0.49134033]),
#  'question_5': array([0.27144551, 0.34573663, 0.39428987, 0.45225834, 0.51105902]),
#  'question_6': array([0.17879566, 0.21923439, 0.24869516, 0.29151949, 0.34653676]),
#  'question_7': array([0.32283916, 0.44933891, 0.51021342, 0.58215219, 0.64887917])}

# %%
df['total'] = df.apply(lambda row: count_total(row.to_dict(), questions_percentiles), axis=1)

# %%
df.columns
# Out:
# Index(['letter_id', 'program', 'average_score', 'mentions_average',
#        'word_count', 'text', 'normalized_text', 'question_1', 'question_2',
#        'question_3', 'question_4', 'question_5', 'question_6', 'question_7',
#        'grammar_errors', 'grammar_errors_description', 'total'],
#       dtype='object')

# %%
df['total'].describe()
# Out:
# count    1317.000000
# mean       25.367502
# std         6.506609
# min         1.000000
# 25%        21.000000
# 50%        26.000000
# 75%        30.000000
# max        41.000000
# Name: total, dtype: float64

# %%
df.to_csv('../data/letters_with_total.csv', index=False)

# %%
df[df['total'] > 35]
# Out:
#      letter_id       program average_score  mentions_average  word_count  \
# 28    14039024  AL Філологія           9.0                 1         881
# 29    13670580  AL Філологія             -                 1         882
# 30    13482056  AL Філологія          11.0                 1         846
# 31    13950221  AL Філологія         11.06                 1         900
# 43    13459164  AL Філологія             -                 1         784
# ...        ...           ...           ...               ...         ...
# 1122  13942517    Психологія         11.05                 1         813
# 1130  13780060    Психологія          10.2                 1         813
# 1132  13787104    Психологія          11.0                 1         869
# 1244  13864036           ЕПЕ          11.0                 1         894
# 1288  13756584           ЕПЕ         10.15                 0         797
#
#                                                    text  \
# 28    Шановний [РЕКТОР]!\nЗвертаюся до Вас з проханн...
# 29    Звертаюся до вас оскільки прагну вступити до У...
# 30    Шановний [РЕКТОР]!\nЯ, [ВСТУПНИК], звертаюся д...
# 31    Шановні працівники приймальної комісії!\nЗверт...
# 43    Шановний [РЕКТОР]!\nЯ пишу цей мотиваційний ли...
# ...                                                 ...
# 1122  Шановні працівники приймальної комісії! Зверта...
# 1130  Шановний [РЕКТОР] !\nЗвертаюся до Вас у зв’язк...
# 1132  Шановний [РЕКТОР]!\nЯ, [ВСТУПНИК], звертаюся д...
# 1244  Шановний [РЕКТОР]!\nЗвертаюся до Вас щодо всту...
# 1288  Шановний пане Тарасе!\nЦього року мені потрібн...
#
#                                         normalized_text  question_1  \
# 28    шановний [ ректор ] ! \n звертатися прохання р...    0.596932
# 29    звертатися оскільки прагнути вступити уку навч...    0.534578
# 30    шановний [ ректор ] ! \n , [ вступник ] , звер...    0.495234
# 31    шановний працівник приймальний комісія ! \n зв...    0.539189
# 43    шановний [ ректор ] ! \n писати мотиваційний л...    0.520156
# ...                                                 ...         ...
# 1122  шановний працівник приймальний комісія ! зверт...    0.496986
# 1130  шановний [ ректор ] ! \n звертатися зв’язку пр...    0.478599
# 1132  шановний [ ректор ] ! \n , [ вступник ] , звер...    0.536643
# 1244  шановний [ ректор ] ! \n звертатися вступ уку ...    0.476938
# 1288  шановний пан тарасе ! \n прийняти складний ріш...    0.530623
#
#       question_2  question_3  question_4  question_5  question_6  question_7  \
# 28      0.504140    0.494713    0.492975    0.505375    0.342913    0.601235
# 29      0.438128    0.482262    0.419886    0.545571    0.300307    0.604112
# 30      0.587268    0.499561    0.466779    0.635140    0.322465    0.621052
# 31      0.533241    0.578218    0.430203    0.493923    0.285583    0.658967
# 43      0.578668    0.526098    0.577952    0.531585    0.345383    0.668762
# ...          ...         ...         ...         ...         ...         ...
# 1122    0.537883    0.442874    0.496743    0.454683    0.302225    0.635013
# 1130    0.470093    0.499812    0.520564    0.466043    0.301258    0.584624
# 1132    0.646651    0.542917    0.528639    0.465719    0.160973    0.765729
# 1244    0.508033    0.503530    0.506397    0.482150    0.346689    0.581971
# 1288    0.416942    0.505867    0.441380    0.461652    0.292883    0.517288
#
#       grammar_errors                         grammar_errors_description  total
# 28                13  [{"message": "\u041a\u0440\u0430\u0449\u0435: ...     37
# 29                 4  [{"message": "\u041f\u0456\u0441\u043b\u044f \...     37
# 30                 5  [{"message": "\u041c\u043e\u0436\u043b\u0438\u...     39
# 31                 8  [{"message": "\u0412\u0441\u0442\u0430\u0432\u...     38
# 43                 7  [{"message": "\u041f\u0440\u0430\u0432\u0438\u...     40
# ...              ...                                                ...    ...
# 1122               8  [{"message": "\u041f\u0435\u0440\u0435\u0434 \...     37
# 1130               5  [{"message": "\u0425\u043e\u0447\u0430 \u0432\...     37
# 1132               4  [{"message": "\u041d\u0435 \u0441\u0442\u0430\...     39
# 1244               9  [{"message": "\u0417\u0433\u0456\u0434\u043d\u...     37
# 1288               4  [{"message": "\u0417\u043d\u0430\u0439\u0434\u...     36
#
# [77 rows x 17 columns]
